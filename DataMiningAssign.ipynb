# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#! pip install mlxtend --user
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
myretaildata = pd.read_excel('http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx')
myretaildata.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
myretaildata['Country']
# Out:
# 0         United Kingdom
# 1         United Kingdom
# 2         United Kingdom
# 3         United Kingdom
# 4         United Kingdom
#                ...
# 541904            France
# 541905            France
# 541906            France
# 541907            France
# 541908            France
# Name: Country, Length: 541909, dtype: object

# %%
myretaildata['Description']=myretaildata['Description'].str.strip()
myretaildata.dropna(axis=0, subset=['InvoiceNo'],inplace=True)
myretaildata['InvoiceNo']=myretaildata['InvoiceNo'].astype('str')
myretaildata=myretaildata[~myretaildata['InvoiceNo'].str.contains('C')]
myretaildata.head(1000)
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 1005    536520     21427             SKULLS STORAGE BOX SMALL         2
# 1006    536520     21034         REX CASH+CARRY JUMBO SHOPPER         2
# 1007    536520     21930             JUMBO STORAGE BAG SKULLS         1
# 1008    536520     20772                  GARDEN PATH JOURNAL         1
# 1009    536520     22469                HEART OF WICKER SMALL         2
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0    2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1    2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2    2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3    2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4    2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 1005 2010-12-01 12:43:00       2.10     14729.0  United Kingdom
# 1006 2010-12-01 12:43:00       0.95     14729.0  United Kingdom
# 1007 2010-12-01 12:43:00       1.95     14729.0  United Kingdom
# 1008 2010-12-01 12:43:00       2.55     14729.0  United Kingdom
# 1009 2010-12-01 12:43:00       1.65     14729.0  United Kingdom
#
# [1000 rows x 8 columns]

# %%
myretaildata['Country'].value_counts()
# Out:
# United Kingdom          487622
# Germany                   9042
# France                    8408
# EIRE                      7894
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1967
# Portugal                  1501
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Unspecified                446
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     295
# Hong Kong                  284
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              25
# Bahrain                     18
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %%
myretaildata.shape
# Out:
# (532621, 8)

# %%
mybasket = (myretaildata[myretaildata['Country']=="Germany"]
           .groupby(['InvoiceNo','Description'])['Quantity']
           .sum().unstack().reset_index().fillna(0)
           .set_index('InvoiceNo'))

# %%
#mybasket.head()
mybasket.head(1500)
#for col in mybasket.columns:
    #print(col)
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                          0.0                         0.0
# 536840                          0.0                         0.0
# 536861                          0.0                         0.0
# 536967                          0.0                         0.0
# 536983                          0.0                         0.0
# ...                             ...                         ...
# 581266                          0.0                         0.0
# 581494                          0.0                         0.0
# 581570                          0.0                         0.0
# 581574                          0.0                         0.0
# 581578                          0.0                         0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
# ...                                       ...
# 581266                                    0.0
# 581494                                    0.0
# 581570                                    0.0
# 581574                                    0.0
# 581578                                    0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536527                                   0.0                            0.0
# 536840                                   0.0                            0.0
# 536861                                   0.0                            0.0
# 536967                                   0.0                            0.0
# 536983                                   0.0                            0.0
# ...                                      ...                            ...
# 581266                                   0.0                            0.0
# 581494                                   0.0                            0.0
# 581570                                   0.0                            0.0
# 581574                                   0.0                            0.0
# 581578                                   0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536527                                       0.0                          0.0
# 536840                                       0.0                          0.0
# 536861                                       0.0                          0.0
# 536967                                       0.0                          0.0
# 536983                                       0.0                          0.0
# ...                                          ...                          ...
# 581266                                       0.0                          0.0
# 581494                                       0.0                          0.0
# 581570                                       0.0                          0.0
# 581574                                       0.0                          0.0
# 581578                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536527                             0.0                                 0.0
# 536840                             0.0                                 0.0
# 536861                             0.0                                 0.0
# 536967                             0.0                                 0.0
# 536983                             0.0                                 0.0
# ...                                ...                                 ...
# 581266                             0.0                                 0.0
# 581494                             0.0                                 0.0
# 581570                             0.0                                 0.0
# 581574                             0.0                                 0.0
# 581578                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE SKULLS  ...  YULETIDE IMAGES GIFT WRAP SET  \
# InvoiceNo                                 ...
# 536527                               0.0  ...                            0.0
# 536840                               0.0  ...                            0.0
# 536861                               0.0  ...                            0.0
# 536967                               0.0  ...                            0.0
# 536983                               0.0  ...                            0.0
# ...                                  ...  ...                            ...
# 581266                               0.0  ...                            0.0
# 581494                               0.0  ...                            0.0
# 581570                               0.0  ...                            0.0
# 581574                               0.0  ...                            0.0
# 581578                               0.0  ...                            0.0
#
# Description  ZINC  HEART T-LIGHT HOLDER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536527                              0.0                        0.0
# 536840                              0.0                        0.0
# 536861                              0.0                        0.0
# 536967                              0.0                        0.0
# 536983                              0.0                        0.0
# ...                                 ...                        ...
# 581266                              0.0                        0.0
# 581494                              0.0                        0.0
# 581570                              0.0                        0.0
# 581574                              0.0                        0.0
# 581578                              0.0                        0.0
#
# Description  ZINC BOX SIGN HOME  ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536527                      0.0                        0.0
# 536840                      0.0                        0.0
# 536861                      0.0                        0.0
# 536967                      0.0                        0.0
# 536983                      0.0                        0.0
# ...                         ...                        ...
# 581266                      0.0                        0.0
# 581494                      0.0                        0.0
# 581570                      0.0                        0.0
# 581574                      0.0                        0.0
# 581578                      0.0                        0.0
#
# Description  ZINC HEART LATTICE T-LIGHT HOLDER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536527                                     0.0                          0.0
# 536840                                     0.0                          0.0
# 536861                                     0.0                          0.0
# 536967                                     0.0                          0.0
# 536983                                     0.0                          0.0
# ...                                        ...                          ...
# 581266                                     0.0                          0.0
# 581494                                     0.0                          0.0
# 581570                                     0.0                          0.0
# 581574                                     0.0                          0.0
# 581578                                     0.0                          0.0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536527                                  0.0                              0.0
# 536840                                  0.0                              0.0
# 536861                                  0.0                              0.0
# 536967                                  0.0                              0.0
# 536983                                  0.0                              0.0
# ...                                     ...                              ...
# 581266                                  0.0                              0.0
# 581494                                  0.0                              0.0
# 581570                                  0.0                              0.0
# 581574                                  0.0                              0.0
# 581578                                  0.0                              0.0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
# ...                                       ...
# 581266                                    0.0
# 581494                                    0.0
# 581570                                    0.0
# 581574                                    0.0
# 581578                                    0.0
#
# [457 rows x 1695 columns]

# %%
def my_encode_units(x):
    if x<=0:
        return 0
    if x>=1:
        return 1
my_basket_sets = mybasket.applymap(my_encode_units)
my_basket_sets.drop('POSTAGE',inplace=True,axis=1)

# %%
#Training Model
my_frequent_itemsets = apriori(my_basket_sets,min_support=0.06, use_colnames=True)#0.07
#my_frequent_itemsets.head(100)

# %%
#Generating Rules
my_rules= association_rules(my_frequent_itemsets, metric="lift", min_threshold=1)

# %%
#viewing top 100 rules
my_rules.head(100)
# Out:
#                              antecedents  \
# 0     (PLASTERS IN TIN WOODLAND ANIMALS)
# 1        (PLASTERS IN TIN CIRCUS PARADE)
# 2     (PLASTERS IN TIN WOODLAND ANIMALS)
# 3             (PLASTERS IN TIN SPACEBOY)
# 4     (PLASTERS IN TIN WOODLAND ANIMALS)
# 5   (ROUND SNACK BOXES SET OF4 WOODLAND)
# 6    (ROUND SNACK BOXES SET OF 4 FRUITS)
# 7   (ROUND SNACK BOXES SET OF4 WOODLAND)
# 8                   (SPACEBOY LUNCH BOX)
# 9   (ROUND SNACK BOXES SET OF4 WOODLAND)
# 10              (WOODLAND CHARLOTTE BAG)
# 11  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#                              consequents  antecedent support  \
# 0        (PLASTERS IN TIN CIRCUS PARADE)            0.137856
# 1     (PLASTERS IN TIN WOODLAND ANIMALS)            0.115974
# 2             (PLASTERS IN TIN SPACEBOY)            0.137856
# 3     (PLASTERS IN TIN WOODLAND ANIMALS)            0.107221
# 4   (ROUND SNACK BOXES SET OF4 WOODLAND)            0.137856
# 5     (PLASTERS IN TIN WOODLAND ANIMALS)            0.245077
# 6   (ROUND SNACK BOXES SET OF4 WOODLAND)            0.157549
# 7    (ROUND SNACK BOXES SET OF 4 FRUITS)            0.245077
# 8   (ROUND SNACK BOXES SET OF4 WOODLAND)            0.102845
# 9                   (SPACEBOY LUNCH BOX)            0.245077
# 10  (ROUND SNACK BOXES SET OF4 WOODLAND)            0.126915
# 11              (WOODLAND CHARLOTTE BAG)            0.245077
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.115974  0.067834    0.492063  4.242887  0.051846    1.740427
# 1             0.137856  0.067834    0.584906  4.242887  0.051846    2.076984
# 2             0.107221  0.061269    0.444444  4.145125  0.046488    1.607002
# 3             0.137856  0.061269    0.571429  4.145125  0.046488    2.011670
# 4             0.245077  0.074398    0.539683  2.202098  0.040613    1.640006
# 5             0.137856  0.074398    0.303571  2.202098  0.040613    1.237951
# 6             0.245077  0.131291    0.833333  3.400298  0.092679    4.529540
# 7             0.157549  0.131291    0.535714  3.400298  0.092679    1.814509
# 8             0.245077  0.070022    0.680851  2.778116  0.044817    2.365427
# 9             0.102845  0.070022    0.285714  2.778116  0.044817    1.256018
# 10            0.245077  0.063457    0.500000  2.040179  0.032354    1.509847
# 11            0.126915  0.063457    0.258929  2.040179  0.032354    1.178139

# %%
#Making Recommendations
my_basket_sets['ROUND SNACK BOXES SET OF4 WOODLAND'].sum()
# Out:
# 112

# %%
my_basket_sets['SPACEBOY LUNCH BOX'].sum()
# Out:
# 47

# %%
df=pd.DataFrame(my_rules)
#df.to_csv("output.csv")

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>
